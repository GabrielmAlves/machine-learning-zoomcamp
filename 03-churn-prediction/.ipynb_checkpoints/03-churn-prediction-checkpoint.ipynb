# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = 'https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-03-churn-prediction/WA_Fn-UseC_-Telco-Customer-Churn.csv'

# %%
# !wget $data -O data-week-3.csv
# Out:
# --2026-03-19 20:13:40--  https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-03-churn-prediction/WA_Fn-UseC_-Telco-Customer-Churn.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 977501 (955K) [text/plain]
# Saving to: ‘data-week-3.csv’
#
# data-week-3.csv     100%[===================>] 954.59K  --.-KB/s    in 0.03s
#
# 2026-03-19 20:13:40 (35.6 MB/s) - ‘data-week-3.csv’ saved [977501/977501]

# %%
df = pd.read_csv(data)
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

categorical_columns = list(df.dtypes[df.dtypes == 'str'].index)

for categorical_column in categorical_columns:
    df[categorical_column] = df[categorical_column].str.lower().str.replace(' ', '_')

# %%
df.head().T
# Out:
#                                  0             1               2  \
# customerid              7590-vhveg    5575-gnvde      3668-qpybk
# gender                      female          male            male
# seniorcitizen                    0             0               0
# partner                        yes            no              no
# dependents                      no            no              no
# tenure                           1            34               2
# phoneservice                    no           yes             yes
# multiplelines     no_phone_service            no              no
# internetservice                dsl           dsl             dsl
# onlinesecurity                  no           yes             yes
# onlinebackup                   yes            no             yes
# deviceprotection                no           yes              no
# techsupport                     no            no              no
# ...

# %%
total_charges = pd.to_numeric(df.totalcharges, errors='coerce')

# %%
df.totalcharges = pd.to_numeric(df.totalcharges, errors='coerce')

# %%
df.totalcharges = df.totalcharges.fillna(0)

# %%
df.churn
# Out:
# 0        no
# 1        no
# 2       yes
# 3        no
# 4       yes
#        ...
# 7038     no
# 7039     no
# 7040     no
# 7041    yes
# 7042     no
# Name: churn, Length: 7043, dtype: str

# %%
df.churn = (df.churn == 'yes').astype('int')

# %%
df.churn
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    1
# 7042    0
# Name: churn, Length: 7043, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
df_full_train, df_test = train_test_split(df, test_size=0.2, random_state=1)

# %%
len(df_full_train), len(df_test)
# Out:
# (5634, 1409)

# %%
## we need to split the train set again to obtain the validation set
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=1)

# %%
len(df_train), len(df_val), len(df_test)
# Out:
# (4225, 1409, 1409)

# %%
## we used 25% because we were splitting the df_full_train, which had 80% of
## the total data from the original dataset
## 20% out 80% means 25%

## now we need to get the y values and delete them after so we don't have a chance of using it
## incorrectly when building the model

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
y_train = df_train.churn.values
y_val = df_val.churn.values
y_test = df_test.churn.values

# %%
del df_train['churn']
del df_val['churn']
del df_test['churn']

# %%
## EDA

df_full_train = df_full_train.reset_index(drop=True)

# %%
df_full_train.churn.value_counts(normalize=True)
# Out:
# churn
# 0    0.730032
# 1    0.269968
# Name: proportion, dtype: float64

# %%
global_churn_rate = df_full_train.churn.mean()
round(global_churn_rate, 2) ## 27% of users are churning
# Out:
# np.float64(0.27)

# %%
numerical = ['tenure', 'monthlycharges', 'totalcharges']

# %%
df_full_train.columns
# Out:
# Index(['customerid', 'gender', 'seniorcitizen', 'partner', 'dependents',
#        'tenure', 'phoneservice', 'multiplelines', 'internetservice',
#        'onlinesecurity', 'onlinebackup', 'deviceprotection', 'techsupport',
#        'streamingtv', 'streamingmovies', 'contract', 'paperlessbilling',
#        'paymentmethod', 'monthlycharges', 'totalcharges', 'churn'],
#       dtype='str')

# %%
categorical = ['gender', 'seniorcitizen', 'partner', 'dependents',
               'phoneservice', 'multiplelines', 'internetservice',
       'onlinesecurity', 'onlinebackup', 'deviceprotection', 'techsupport',
       'streamingtv', 'streamingmovies', 'contract', 'paperlessbilling',
       'paymentmethod']

# %%
df_full_train[categorical].nunique()
# Out:
# gender              2
# seniorcitizen       2
# partner             2
# dependents          2
# phoneservice        2
# multiplelines       3
# internetservice     3
# onlinesecurity      3
# onlinebackup        3
# deviceprotection    3
# techsupport         3
# streamingtv         3
# streamingmovies     3
# contract            3
# paperlessbilling    2
# paymentmethod       4
# dtype: int64

# %%
## looking churn rates in different groups

# %%
df_full_train.head()
# Out:
#    customerid  gender  seniorcitizen partner dependents  tenure phoneservice  \
# 0  5442-pptjy    male              0     yes        yes      12          yes
# 1  6261-rcvns  female              0      no         no      42          yes
# 2  2176-osjuv    male              0     yes         no      71          yes
# 3  6161-erdgd    male              0     yes        yes      71          yes
# 4  2364-ufrom    male              0      no         no      30          yes
#
#   multiplelines internetservice       onlinesecurity  ...  \
# 0            no              no  no_internet_service  ...
# 1            no             dsl                  yes  ...
# 2           yes             dsl                  yes  ...
# 3           yes             dsl                  yes  ...
# 4            no             dsl                  yes  ...
#
#       deviceprotection          techsupport          streamingtv  \
# 0  no_internet_service  no_internet_service  no_internet_service
# ...

# %%
churn_female = df_full_train[df_full_train.gender == 'female'].churn.mean()
churn_female
# Out:
# np.float64(0.27682403433476394)

# %%
churn_male = df_full_train[df_full_train.gender == 'male'].churn.mean()
churn_male
# Out:
# np.float64(0.2632135306553911)

# %%
df_full_train.partner.value_counts()
# Out:
# partner
# no     2932
# yes    2702
# Name: count, dtype: int64

# %%
churn_with_partner = df_full_train[df_full_train.partner == 'yes'].churn.mean()
churn_with_partner
# Out:
# np.float64(0.20503330866025166)

# %%
churn_no_partner = df_full_train[df_full_train.partner == 'no'].churn.mean()
churn_no_partner
# Out:
# np.float64(0.3298090040927694)

# %%
global_churn_rate - churn_with_partner, global_churn_rate - churn_no_partner
# Out:
# (np.float64(0.06493474245795922), np.float64(-0.05984095297455855))

# %%
## this gives an idea that the partner variable is more important to predict churn
## than the partner variable

# %%
## we can also calculate the risk ratio

churn_with_partner / global_churn_rate
# Out:
# np.float64(0.7594724924338315)

# %%
churn_no_partner / global_churn_rate
# Out:
# np.float64(1.2216593879412643)

# %%
## risk = group divided by the global churn rate
## if it is more than 1, it is more likely to churn
## if less, it is less likely to churn

from IPython.display import display

# %%
for c in categorical:
    print(c)
    df_group = df_full_train.groupby(c).churn.agg(['mean', 'count'])
    df_group['diff'] = df_group['mean'] - global_churn_rate
    df_group['risk'] = df_group['mean'] / global_churn_rate

    display(df_group)
    print()
    print()
# Out:
# gender
#             mean  count      diff      risk
# gender
# female  0.276824   2796  0.006856  1.025396
# male    0.263214   2838 -0.006755  0.974980
# seniorcitizen
#                    mean  count      diff      risk
# seniorcitizen
# 0              0.242270   4722 -0.027698  0.897403
# 1              0.413377    912  0.143409  1.531208
# partner
#              mean  count      diff      risk
# partner
# no       0.329809   2932  0.059841  1.221659
# yes      0.205033   2702 -0.064935  0.759472
# dependents
#                 mean  count      diff      risk
# dependents
# no          0.313760   3968  0.043792  1.162212
# yes         0.165666   1666 -0.104302  0.613651
# phoneservice
#                   mean  count      diff      risk
# phoneservice
# no            0.241316    547 -0.028652  0.893870
# yes           0.273049   5087  0.003081  1.011412
# multiplelines
#                       mean  count      diff      risk
# multiplelines
# ...

# %%
## using mutual information to understand how important each variable is
## the more we learn about churn by observing the value of other variable

# %%
from sklearn.metrics import mutual_info_score

# %%
mutual_info_score(df_full_train.churn, df_full_train.contract)
# Out:
# 0.0983203874041556

# %%
mutual_info_score(df_full_train.churn, df_full_train.gender)
# Out:
# 0.0001174846211139946

# %%
def mutual_info_churn_score(series):
    return mutual_info_score(series, df_full_train.churn)

# %%
mutual_information = df_full_train[categorical].apply(mutual_info_churn_score) ## the mutual information score for each column

mutual_information.sort_values(ascending=False)
# Out:
# contract            0.098320
# onlinesecurity      0.063085
# techsupport         0.061032
# internetservice     0.055868
# onlinebackup        0.046923
# deviceprotection    0.043453
# paymentmethod       0.043210
# streamingtv         0.031853
# streamingmovies     0.031581
# paperlessbilling    0.017589
# dependents          0.012346
# partner             0.009968
# seniorcitizen       0.009410
# multiplelines       0.000857
# phoneservice        0.000229
# gender              0.000117
# dtype: float64

# %%
## measuring correlation, which is a way to measure feature importance for
## numerical values
## measure dependency between variables

# %%
df_full_train[numerical].corrwith(df_full_train.churn)
# Out:
# tenure           -0.351885
# monthlycharges    0.196805
# totalcharges     -0.196353
# dtype: float64

# %%
df_full_train[(df_full_train.tenure > 2) & (df_full_train.tenure <= 12)].churn.mean()
# Out:
# np.float64(0.3994413407821229)

# %%
df_full_train[df_full_train.tenure > 12].churn.mean()
# Out:
# np.float64(0.17634908339788277)

# %%
df_full_train[df_full_train.monthlycharges <= 20].churn.mean()
# Out:
# np.float64(0.08795411089866156)

# %%
df_full_train[(df_full_train.monthlycharges > 20) & (df_full_train.monthlycharges <= 50)].churn.mean()
# Out:
# np.float64(0.18340943683409436)

# %%
df_full_train[df_full_train.monthlycharges > 50].churn.mean()
# Out:
# np.float64(0.32499341585462205)

# %%
## one-hot encoding to encode categorical variables
## using DictVectorizer we first need to convert our dataframe into a dictionary
## and we feed our DictVectorizer object with our dictionary so it can verify the columns and its values
## and generate the encoding

# %%
from sklearn.feature_extraction import DictVectorizer

# %%
train_dicts = df_train[categorical + numerical].to_dict(orient='records')
train_dicts[0]
# Out:
# {'gender': 'female',
#  'seniorcitizen': 0,
#  'partner': 'yes',
#  'dependents': 'yes',
#  'phoneservice': 'yes',
#  'multiplelines': 'yes',
#  'internetservice': 'fiber_optic',
#  'onlinesecurity': 'yes',
#  'onlinebackup': 'yes',
#  'deviceprotection': 'yes',
#  'techsupport': 'yes',
#  'streamingtv': 'yes',
#  'streamingmovies': 'yes',
#  'contract': 'two_year',
#  'paperlessbilling': 'yes',
#  'paymentmethod': 'electronic_check',
#  'tenure': 72,
#  'monthlycharges': 115.5,
#  'totalcharges': 8425.15}

# %%
dv = DictVectorizer(sparse=False)

# %%
X_train = dv.fit_transform(train_dicts)

# %%
X_train.shape
# Out:
# (4225, 45)

# %%
val_dicts = df_val[categorical + numerical].to_dict(orient='records')

# %%
X_val = dv.transform(val_dicts)

# %%
## logistic regression
## it uses the same function as linear regression -> g(xi) = w0 + wt*xi 
## but instead of returning any real number (like linear regression), it returns either 0 or 1
## by applying a sigmoid function on it

## the output of of g is a score and with obtain a probability by using sigmoid

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# %%
z = np.linspace(-7, 7, 51)
z
# Out:
# array([-7.0000000e+00, -6.7200000e+00, -6.4400000e+00, -6.1600000e+00,
#        -5.8800000e+00, -5.6000000e+00, -5.3200000e+00, -5.0400000e+00,
#        -4.7600000e+00, -4.4800000e+00, -4.2000000e+00, -3.9200000e+00,
#        -3.6400000e+00, -3.3600000e+00, -3.0800000e+00, -2.8000000e+00,
#        -2.5200000e+00, -2.2400000e+00, -1.9600000e+00, -1.6800000e+00,
#        -1.4000000e+00, -1.1200000e+00, -8.4000000e-01, -5.6000000e-01,
#        -2.8000000e-01,  8.8817842e-16,  2.8000000e-01,  5.6000000e-01,
#         8.4000000e-01,  1.1200000e+00,  1.4000000e+00,  1.6800000e+00,
#         1.9600000e+00,  2.2400000e+00,  2.5200000e+00,  2.8000000e+00,
#         3.0800000e+00,  3.3600000e+00,  3.6400000e+00,  3.9200000e+00,
#         4.2000000e+00,  4.4800000e+00,  4.7600000e+00,  5.0400000e+00,
#         5.3200000e+00,  5.6000000e+00,  5.8800000e+00,  6.1600000e+00,
#         6.4400000e+00,  6.7200000e+00,  7.0000000e+00])

# %%
sigmoid(z)
# Out:
# array([9.11051194e-04, 1.20508423e-03, 1.59386223e-03, 2.10780106e-03,
#        2.78699622e-03, 3.68423990e-03, 4.86893124e-03, 6.43210847e-03,
#        8.49286285e-03, 1.12064063e-02, 1.47740317e-02, 1.94550846e-02,
#        2.55807883e-02, 3.35692233e-02, 4.39398154e-02, 5.73241759e-02,
#        7.44679452e-02, 9.62155417e-02, 1.23467048e-01, 1.57095469e-01,
#        1.97816111e-01, 2.46011284e-01, 3.01534784e-01, 3.63547460e-01,
#        4.30453776e-01, 5.00000000e-01, 5.69546224e-01, 6.36452540e-01,
#        6.98465216e-01, 7.53988716e-01, 8.02183889e-01, 8.42904531e-01,
#        8.76532952e-01, 9.03784458e-01, 9.25532055e-01, 9.42675824e-01,
#        9.56060185e-01, 9.66430777e-01, 9.74419212e-01, 9.80544915e-01,
#        9.85225968e-01, 9.88793594e-01, 9.91507137e-01, 9.93567892e-01,
#        9.95131069e-01, 9.96315760e-01, 9.97213004e-01, 9.97892199e-01,
#        9.98406138e-01, 9.98794916e-01, 9.99088949e-01])

# %%
plt.plot(z, sigmoid(z))

# %%
def linear_regression(xi):
    result = w0

    for j in range(len(w)):
        result = result + xi[j] * w[j]
    
    return result

# %%
def logistic_regression(xi):
    score = w0

    for j in range(len(w)):
        score = score + xi[j] * w[j]

    result = sigmoid(score)
    return result

# %%
## they both are called linear because of the dot product, and dot product is called a linear operator

# %%
## training logistic regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.intercept_
# Out:
# array([-0.11092874])

# %%
model.predict(X_train) ## hard predictions
## hard predictions has the exact labels, we don't know the probability
# Out:
# array([0, 1, 1, ..., 1, 0, 1], shape=(4225,))

# %%
## to see the probability, use predict_proba
## it produces soft predictions
model.predict_proba(X_val)
# Out:
# array([[0.99213653, 0.00786347],
#        [0.79007197, 0.20992803],
#        [0.7762895 , 0.2237105 ],
#        ...,
#        [0.84985131, 0.15014869],
#        [0.22331887, 0.77668113],
#        [0.18964226, 0.81035774]], shape=(1409, 2))

# %%
## the second column of the above array is the positive probability (1)

# %%
y_pred = model.predict_proba(X_val)[:, 1] ## takes only the second column

# %%
churn_decision = (y_pred >= 0.5)

# %%
df_val[churn_decision].customerid
# Out:
# 3       8433-wxgna
# 8       3440-jpscl
# 11      2637-fkfsy
# 12      7228-omtpn
# 19      6711-fldfb
#            ...
# 1397    5976-jcjrh
# 1398    2034-cgrhz
# 1399    5276-kqwhg
# 1407    6521-yytyi
# 1408    3049-solay
# Name: customerid, Length: 322, dtype: str

# %%
(y_val == churn_decision).mean()
# Out:
# np.float64(0.801277501774308)

# %%
df_pred = pd.DataFrame()
df_pred['probability'] = y_pred
df_pred['prediction'] = churn_decision.astype(int)
df_pred['actual'] = y_val

# %%
df_pred
# Out:
#       probability  prediction  actual
# 0        0.007863           0       0
# 1        0.209928           0       0
# 2        0.223710           0       0
# 3        0.561123           1       1
# 4        0.219586           0       0
# ...           ...         ...     ...
# 1404     0.297790           0       0
# 1405     0.035463           0       1
# 1406     0.150149           0       0
# 1407     0.776681           1       1
# 1408     0.810358           1       1
#
# [1409 rows x 3 columns]

# %%
df_pred['correct'] = df_pred.prediction == df_pred.actual

# %%
df_pred
# Out:
#       probability  prediction  actual  correct
# 0        0.007863           0       0     True
# 1        0.209928           0       0     True
# 2        0.223710           0       0     True
# 3        0.561123           1       1     True
# 4        0.219586           0       0     True
# ...           ...         ...     ...      ...
# 1404     0.297790           0       0     True
# 1405     0.035463           0       1    False
# 1406     0.150149           0       0     True
# 1407     0.776681           1       1     True
# 1408     0.810358           1       1     True
#
# [1409 rows x 4 columns]

# %%
df_pred.correct.mean()
# Out:
# np.float64(0.801277501774308)

# %%
## zip concatenates the values from two lists into one unique list
## example:
## a = [1, 2, 3, 4]
## b = 'abcd'

## zip -> 1a, 2b, 3c, 4d
## so we are using it to match a weight value to a certain feature
dict(zip(dv.feature_names_, model.coef_[0].round(3)))
# Out:
# {'contract=month-to-month': np.float64(0.564),
#  'contract=one_year': np.float64(-0.154),
#  'contract=two_year': np.float64(-0.519),
#  'dependents=no': np.float64(-0.013),
#  'dependents=yes': np.float64(-0.095),
#  'deviceprotection=no': np.float64(0.071),
#  'deviceprotection=no_internet_service': np.float64(-0.098),
#  'deviceprotection=yes': np.float64(-0.082),
#  'gender=female': np.float64(-0.033),
#  'gender=male': np.float64(-0.076),
#  'internetservice=dsl': np.float64(-0.354),
#  'internetservice=fiber_optic': np.float64(0.343),
#  'internetservice=no': np.float64(-0.098),
#  'monthlycharges': np.float64(0.002),
#  'multiplelines=no': np.float64(-0.251),
#  'multiplelines=no_phone_service': np.float64(0.162),
#  'multiplelines=yes': np.float64(-0.02),
#  'onlinebackup=no': np.float64(0.066),
#  'onlinebackup=no_internet_service': np.float64(-0.098),
#  'onlinebackup=yes': np.float64(-0.076),
#  'onlinesecurity=no': np.float64(0.251),
# ...

# %%
## we can train a smaller model using a subset of features

small = ['contract', 'tenure', 'monthlycharges']

# %%
df_train[small].iloc[:10].to_dict(orient='records')
## we can use that for our vectorizer, which will encode it
# Out:
# [{'contract': 'two_year', 'tenure': 72, 'monthlycharges': 115.5},
#  {'contract': 'month-to-month', 'tenure': 10, 'monthlycharges': 95.25},
#  {'contract': 'month-to-month', 'tenure': 5, 'monthlycharges': 75.55},
#  {'contract': 'month-to-month', 'tenure': 5, 'monthlycharges': 80.85},
#  {'contract': 'two_year', 'tenure': 18, 'monthlycharges': 20.1},
#  {'contract': 'month-to-month', 'tenure': 4, 'monthlycharges': 30.5},
#  {'contract': 'month-to-month', 'tenure': 1, 'monthlycharges': 75.1},
#  {'contract': 'month-to-month', 'tenure': 1, 'monthlycharges': 70.3},
#  {'contract': 'two_year', 'tenure': 72, 'monthlycharges': 19.75},
#  {'contract': 'month-to-month', 'tenure': 6, 'monthlycharges': 109.9}]

# %%
dicts_train_small = df_train[small].to_dict(orient='records')
dicts_val_small = df_val[small].to_dict(orient='records')

# %%
dv_small = DictVectorizer(sparse=False)
dv_small.fit(dicts_train_small)
# Out:
# DictVectorizer(sparse=False)

# %%
dv_small.feature_names_
# Out:
# ['contract=month-to-month',
#  'contract=one_year',
#  'contract=two_year',
#  'monthlycharges',
#  'tenure']

# %%
X_train_small = dv_small.transform(dicts_train_small)

# %%
model_small = LogisticRegression()
model_small.fit(X_train_small, y_train)
# Out:
# LogisticRegression()

# %%
## bias term
w0 = model_small.intercept_[0] 
w0
# Out:
# np.float64(-2.477957595829565)

# %%
## weights
w = model_small.coef_[0]
w.round(3)
# Out:
# array([ 0.971, -0.024, -0.948,  0.027, -0.036])

# %%
dict(zip(dv_small.feature_names_, w.round(3)))
# Out:
# {'contract=month-to-month': np.float64(0.971),
#  'contract=one_year': np.float64(-0.024),
#  'contract=two_year': np.float64(-0.948),
#  'monthlycharges': np.float64(0.027),
#  'tenure': np.float64(-0.036)}

# %%
## model interpretation

## w0 + wi*xi
## if customer has a monthly contract
## -2.47 +  1 * 0.97  + 0 * (-0.024) + 0 * (-0.948)        CONTRACT
##  +  50 *  0.027       MONTHLY CHARGES
##  +  5 * (-0.036)         TENURE

## you see that on the contract part, where it has a 0 encoded
## get cancelled because we multiplied by zero

-2.47 + -0.948 + 30 * 0.024 + 24 * (-0.036)
# Out:
# -3.5620000000000003

# %%
sigmoid(_)
# Out:
# np.float64(0.027598697562527152)

# %%
## for variables that has negative weight, they tend to churn less

# %%
## using the model

# %%
dicts_full_train = df_full_train[categorical + numerical].to_dict(orient='records')

# %%
dv = DictVectorizer(sparse=False)
X_full_train = dv.fit_transform(dicts_full_train)

y_full_train = df_full_train.churn.values

# %%
model = LogisticRegression()
model.fit(X_full_train, y_full_train)
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
dicts_test = df_test[categorical + numerical].to_dict(orient='records')

# %%
X_test = dv.transform(dicts_test)

# %%
y_pred = model.predict_proba(X_test)[:, 1]

# %%
churn_decision = (y_pred >= 0.5)

# %%
(churn_decision == y_test).mean()
# Out:
# np.float64(0.8140525195173882)

# %%
customer = dicts_test[-1]
customer
# Out:
# {'gender': 'female',
#  'seniorcitizen': 0,
#  'partner': 'yes',
#  'dependents': 'yes',
#  'phoneservice': 'yes',
#  'multiplelines': 'yes',
#  'internetservice': 'fiber_optic',
#  'onlinesecurity': 'yes',
#  'onlinebackup': 'no',
#  'deviceprotection': 'yes',
#  'techsupport': 'no',
#  'streamingtv': 'yes',
#  'streamingmovies': 'yes',
#  'contract': 'month-to-month',
#  'paperlessbilling': 'yes',
#  'paymentmethod': 'electronic_check',
#  'tenure': 17,
#  'monthlycharges': 104.2,
#  'totalcharges': 1743.5}

# %%
X_small = dv.transform([customer])

# %%
model.predict_proba(X_small)
# Out:
# array([[0.33865299, 0.66134701]])

# %%
y_test[-1]
# Out:
# np.int64(1)

# %%
## accuracy
## is how much was correct in overall
## example:
## if we predicted the churn decision of 6 people and only 3 of them was right
## accuracy = 3 out of 6 = 50%

# %%
len(y_val)
# Out:
# 1409

# %%
## we make a prediction for all of this costumers

# %%
(y_val == churn_decision).mean()
# Out:
# np.float64(0.6167494677075941)

# %%
## the number of correct predictions divided by the total number
## 869 / 1409

896 / 1409
# Out:
# 0.6359119943222143

# %%
## we used 0.5 as threshold, but is it good enough?
from sklearn.metrics import accuracy_score

thresholds = np.linspace(0, 1, 21)
scores = []

for t in thresholds:
    score = accuracy_score(y_val, y_pred >= t)
    print('%.2f %.3f' % (t, score))
    scores.append(score)
# Out:
# 0.00 0.274
# 0.05 0.404
# 0.10 0.451
# 0.15 0.480
# 0.20 0.505
# 0.25 0.533
# 0.30 0.537
# 0.35 0.560
# 0.40 0.575
# 0.45 0.588
# 0.50 0.617
# 0.55 0.627
# 0.60 0.647
# 0.65 0.674
# 0.70 0.691
# 0.75 0.710
# 0.80 0.720
# 0.85 0.726
# 0.90 0.726
# 0.95 0.726
# 1.00 0.726

# %%
plt.plot(thresholds, scores)

# %%
from collections import Counter

Counter(y_pred >= 1.0)
# Out:
# Counter({np.False_: 1409})

# %%
## accuracy doesn't tell us how good the model is
Counter(y_val)

## we have a lot more non churning users than churning ones
y_val.mean() ## 27% are churning
1 - y_val.mean() ## 72% are non churning
# Out:
# np.float64(0.7260468417317246)

# %%
## this is class imbalance
## we have a lot more costumers who are non churning than churning ones
## 3x more non churning people
## this is why these dummy models will already have good accuracy when predicting the majority class
## accuracy for cases with class imbalance can be misleading

# %%
## confusion table

# %%
## we need a different way of evaluating the quality of our model
## that isn't impacted by class imbalance

##                 g(xi)
## (NEGATIVE) /                    \ (POSITIVE)
##      NO CHURN                 CHURN
##    /        \               /        \
## CUSTOMER     CUSTOMER   CUSTOMER  CUSTOMER
## DIDN'T       CHURNED    DIDN'T    CHURNED  (TRUE POSITIVE)
## CHURN        (FN)       CHURN (FALSE POSITIVE)
## (TRUE 
## NEGATIVE)

# %%
## TRUE POSITIVE -> we predicted that the customer is going to churn and it indeed was going to churn
## g(xi) >= threshold && y = 1
## TRUE NEGATIVE -> we predicted that the customer is not going to churn and it indeed was not going to churn
## g(xi) < threshold && y = 0
## FALSE POSITIVE -> we predicted that the customer is going to churn but it isn't
## g(xi) >= threshold && y = 0
## FALSE NEGATIVE -> we predicted that the customer is not going to churn but it is
## g(xi) < threshold && y = 1

# %%
actual_positive = (y_val == 1)
actual_negative = (y_val == 0)

# %%
t = 0.5
predict_positive = (y_pred >= t)
predict_negative = (y_pred < t)

# %%
tp = (predict_positive & actual_positive).sum()
tn = (predict_negative & actual_negative).sum()

# %%
tn
# Out:
# np.int64(785)

# %%
fp = (predict_positive & actual_negative).sum()
fn = (predict_negative & actual_positive).sum()

# %%
fp, fn
# Out:
# (np.int64(238), np.int64(302))

# %%
## confusion matrix
##                         PREDICTIONS
## ACTUAL           NEGATIVE         POSITIVE
##     NEGATIVE       TN                FP
##     POSITIVE       FN                TP

confusion_matrix = np.array([
    [tn, fp],
    [fn, tp]
])

confusion_matrix
# Out:
# array([[785, 238],
#        [302,  84]])

# %%
(confusion_matrix / confusion_matrix.sum()).round(2)
# Out:
# array([[0.56, 0.17],
#        [0.21, 0.06]])

# %%
## precision and recall

## precision tell us a fraction of positive predictions turned out to be correct
## we predicted that some customers are churning, so how many of those are correct (TP)

precision = tp / (tp + fp)
precision
# Out:
# np.float64(0.2608695652173913)

# %%
## recall doesn't look at fraction of positive predictions
## we will look into fraction of churning users that we identified correctly
## it is out of the total positive number, how many were correctly classified as positive
## if we have 4 people that are positive but one of them wasn't identified as churning
## then we have 3 / 4 correctly identified but one that was indeed positive was classified as negative

recall = tp / (tp + fn)
recall
# Out:
# np.float64(0.21761658031088082)

# %%
## failed to identify 76% (recall) positive users so we lost customers (lose money)
## sent promotional e-mail to 64% of customers that shouldn't receive discount

## basically, precision tell us:
## ok, we predicted 4 people as positive. but how many of them are really positive?
## so it take under consideration all TRUE POSITIVE out of the total of positive classified
## recall says:
## ok, we predicted 4 people as positive. but how many of the negative ones are actually positive?
## it looks at the FALSE NEGATIVE, so, the ones that were actually positive but were classified as
## negative

# %%
## ROC curves
## TPR and FRP

tpr = tp / (tp + fn)
tpr
# Out:
# np.float64(0.21761658031088082)

# %%
fpr = fp / (fp + tn)
fpr
# Out:
# np.float64(0.23264907135874877)

# %%
## roc curve is good how: instead of evaluating these 2 values through one threshold,
## it looks at all possible thresholds, for each threshold we can think of, it evaluates these qualities

# %%
scores = []

thresholds = np.linspace(0, 1, 101)

for t in thresholds:
    actual_positive = (y_val == 1)
    actual_negative = (y_val == 0)

    predict_positive = (y_pred >= t)
    predict_negative = (y_pred < t)

    tp = (predict_positive & actual_positive).sum()
    tn = (predict_negative & actual_negative).sum()

    fp = (predict_positive & actual_negative).sum()
    fn = (predict_negative & actual_positive).sum()

    scores.append((t, tp, fp, fn, tn))

# %%
columns = ['threshold', 'tp', 'fp', 'fn', 'tn']
df_scores = pd.DataFrame(scores, columns=columns)

# %%
df_scores['tpr'] = df_scores.tp / (df_scores.tp + df_scores.fn)
df_scores['fpr'] = df_scores.fp / (df_scores.fp + df_scores.tn)

# %%
df_scores[::10]
# Out:
#      threshold   tp    fp   fn    tn       tpr       fpr
# 0          0.0  386  1023    0     0  1.000000  1.000000
# 10         0.1  251   639  135   384  0.650259  0.624633
# 20         0.2  183   495  203   528  0.474093  0.483871
# 30         0.3  136   402  250   621  0.352332  0.392962
# 40         0.4  111   324  275   699  0.287565  0.316716
# 50         0.5   84   238  302   785  0.217617  0.232649
# 60         0.6   51   162  335   861  0.132124  0.158358
# 70         0.7   27    76  359   947  0.069948  0.074291
# 80         0.8    2    11  384  1012  0.005181  0.010753
# 90         0.9    0     0  386  1023  0.000000  0.000000
# 100        1.0    0     0  386  1023  0.000000  0.000000

# %%
plt.plot(df_scores.threshold, df_scores['tpr'], label='TPR')
plt.plot(df_scores.threshold, df_scores['fpr'], label='FPR')
plt.legend()

# %%
## random model
np.random.seed(1)
y_rand = np.random.uniform(0, 1, size=len(y_val))

# %%
((y_rand >= 0.5) == y_val).mean()
# Out:
# np.float64(0.5017743080198722)

# %%
def tpr_fpr_dataframe(y_val, y_pred):
    scores = []

    thresholds = np.linspace(0, 1, 101)
    
    for t in thresholds:
        actual_positive = (y_val == 1)
        actual_negative = (y_val == 0)
    
        predict_positive = (y_pred >= t)
        predict_negative = (y_pred < t)
    
        tp = (predict_positive & actual_positive).sum()
        tn = (predict_negative & actual_negative).sum()
    
        fp = (predict_positive & actual_negative).sum()
        fn = (predict_negative & actual_positive).sum()
    
        scores.append((t, tp, fp, fn, tn))
    columns = ['threshold', 'tp', 'fp', 'fn', 'tn']
    df_scores = pd.DataFrame(scores, columns=columns)

    df_scores['tpr'] = df_scores.tp / (df_scores.tp + df_scores.fn)
    df_scores['fpr'] = df_scores.fp / (df_scores.fp + df_scores.tn)

    return df_scores

# %%
df_rand = tpr_fpr_dataframe(y_val, y_rand)

# %%
df_rand[::10]
# Out:
#      threshold   tp    fp   fn    tn       tpr       fpr
# 0          0.0  386  1023    0     0  1.000000  1.000000
# 10         0.1  347   923   39   100  0.898964  0.902248
# 20         0.2  307   822   79   201  0.795337  0.803519
# 30         0.3  276   724  110   299  0.715026  0.707722
# 40         0.4  237   624  149   399  0.613990  0.609971
# 50         0.5  202   518  184   505  0.523316  0.506354
# 60         0.6  161   409  225   614  0.417098  0.399804
# 70         0.7  121   302  265   721  0.313472  0.295210
# 80         0.8   78   206  308   817  0.202073  0.201369
# 90         0.9   40   101  346   922  0.103627  0.098729
# 100        1.0    0     0  386  1023  0.000000  0.000000

# %%
plt.plot(df_rand.threshold, df_rand['tpr'], label='TPR')
plt.plot(df_rand.threshold, df_rand['fpr'], label='FPR')
plt.legend()

# %%
num_neg = (y_val == 0).sum()
num_pos = (y_val == 1).sum()
num_neg, num_pos
# Out:
# (np.int64(1023), np.int64(386))

# %%
y_ideal = np.repeat([0, 1], [num_neg, num_pos])
y_ideal
# Out:
# array([0, 0, 0, ..., 1, 1, 1], shape=(1409,))

# %%
y_ideal_pred = np.linspace(0, 1, len(y_val))

# %%
((y_ideal_pred >= 0.726) == y_ideal).mean()
# Out:
# np.float64(1.0)

# %%
## ^ the ideal model

# %%
df_ideal = tpr_fpr_dataframe(y_ideal, y_ideal_pred)

# %%
df_ideal[::10]
# Out:
#      threshold   tp    fp   fn    tn       tpr       fpr
# 0          0.0  386  1023    0     0  1.000000  1.000000
# 10         0.1  386   882    0   141  1.000000  0.862170
# 20         0.2  386   741    0   282  1.000000  0.724340
# 30         0.3  386   600    0   423  1.000000  0.586510
# 40         0.4  386   459    0   564  1.000000  0.448680
# 50         0.5  386   319    0   704  1.000000  0.311828
# 60         0.6  386   178    0   845  1.000000  0.173998
# 70         0.7  386    37    0   986  1.000000  0.036168
# 80         0.8  282     0  104  1023  0.730570  0.000000
# 90         0.9  141     0  245  1023  0.365285  0.000000
# 100        1.0    1     0  385  1023  0.002591  0.000000

# %%
plt.plot(df_ideal.threshold, df_ideal['tpr'], label='TPR')
plt.plot(df_ideal.threshold, df_ideal['fpr'], label='FPR')
plt.legend()

# %%
plt.plot(df_scores.threshold, df_scores['tpr'], label='TPR')
plt.plot(df_scores.threshold, df_scores['fpr'], label='FPR')

# plt.plot(df_rand.threshold, df_rand['tpr'], label='TPR')
# plt.plot(df_rand.threshold, df_rand['fpr'], label='FPR')

plt.plot(df_ideal.threshold, df_ideal['tpr'], label='TPR', color='black')
plt.plot(df_ideal.threshold, df_ideal['fpr'], label='FPR', color='black')
plt.legend()

# %%
plt.figure(figsize=(5, 5))

plt.plot(df_scores.fpr, df_scores.tpr, label='model')
plt.plot(df_rand.fpr, df_rand.tpr, label='random')
plt.plot(df_ideal.fpr, df_ideal.tpr, label='ideal')

plt.xlabel('FPR')
plt.ylabel('TPR')

plt.legend()
